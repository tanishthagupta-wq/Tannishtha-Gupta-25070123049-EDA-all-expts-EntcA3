# %% [markdown]
# # Experiment 11
# ### Name: Tannishtha Gupta
# ### PRN: 25070123049
# ### Batch: A3
# #### Title: Categorical Data Analysis using Python

# %%
import pandas as pd

data = {
    'Order_ID': ['01', '02', '03', '04', '05', '06', '07', '08', '09', '010'],

    'Category': ['Electronics', 'Clothing', 'Electronics', 'Grocery', 'Clothing', 'Electronics', 'Grocery','Clothing', 'Electronics', 'Grocery'],

    'Payment_Method': ['UPI', 'Card', 'UPI', 'Cash', 'Card', 'UPI', 'Cash', 'Card', 'UPI', 'Cash'],

    'Delivery_Type': ['Express', 'Standard', 'Express', 'Standard', 'Express', 'Standard', 'Express', 'Standard', 'Express', 'Standard'],

    'Customer_Type': ['New', 'Returning', 'Returning', 'New', 'Returning', 'New', 'Returning', 'New', 'Returning', 'New']
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 0       01  Electronics            UPI       Express           New
# 1       02     Clothing           Card      Standard     Returning
# 2       03  Electronics            UPI       Express     Returning
# 3       04      Grocery           Cash      Standard           New
# 4       05     Clothing           Card       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 6       07      Grocery           Cash       Express     Returning
# 7       08     Clothing           Card      Standard           New
# 8       09  Electronics            UPI       Express     Returning
# 9      010      Grocery           Cash      Standard           New

# %%
#1. Frequency Count
# Count how many orders are in each category.

print(df['Category'].value_counts())
# Out:
# Category
# Electronics    4
# Clothing       3
# Grocery        3
# Name: count, dtype: int64

# %%
#2. Unique Values
#Display all unique categories

print(df['Category'].unique())
# Out:
# ['Electronics' 'Clothing' 'Grocery']

# %%
#3. Numbr of Unique Values
print(df['Category'].nunique())
# Out:
# 3

# %%
#4. Cross Tabulation
#Category Vs Payment Method

print(pd.crosstab(df['Category'], df['Payment_Method']))
# Out:
# Payment_Method  Card  Cash  UPI
# Category
# Clothing           3     0    0
# Electronics        0     0    4
# Grocery            0     3    0

# %%
#5. Cross Tabulation
#Delivery Vs Customer Type

print(pd.crosstab(df['Delivery_Type'], df['Customer_Type']))
# Out:
# Customer_Type  New  Returning
# Delivery_Type
# Express          1          4
# Standard         4          1

# %%
#7. Percentage Distribution

print(df['Category'].value_counts(normalize=True)*100)
# Out:
# Category
# Electronics    40.0
# Clothing       30.0
# Grocery        30.0
# Name: proportion, dtype: float64

# %%
#8. Filtering Data
# Example: Orders from Electronics Category

electronics_orders = df[df['Category']=='Electronics']
print(electronics_orders)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 0       01  Electronics            UPI       Express           New
# 2       03  Electronics            UPI       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 8       09  Electronics            UPI       Express     Returning

# %%
#9. Grouping
#Orders by category and payment method

print(df.groupby('Category')['Payment_Method'].value_counts())
# Out:
# Category     Payment_Method
# Clothing     Card              3
# Electronics  UPI               4
# Grocery      Cash              3
# Name: count, dtype: int64

# %%
#10. Sorting Data

sorted_df = df.sort_values(by='Category')
print(sorted_df)
# Out:
#   Order_ID     Category Payment_Method Delivery_Type Customer_Type
# 1       02     Clothing           Card      Standard     Returning
# 4       05     Clothing           Card       Express     Returning
# 7       08     Clothing           Card      Standard           New
# 0       01  Electronics            UPI       Express           New
# 2       03  Electronics            UPI       Express     Returning
# 5       06  Electronics            UPI      Standard           New
# 8       09  Electronics            UPI       Express     Returning
# 3       04      Grocery           Cash      Standard           New
# 6       07      Grocery           Cash       Express     Returning
# 9      010      Grocery           Cash      Standard           New

# %%
#Second Dataset
import pandas as pd

df = pd.read_csv("/content/Expt11.csv")

print(df.head())#Second Dataset
import pandas as pd

df = pd.read_csv("/content/Expt11.csv")

print(df.head())
# Out:
#   Student  Gender Department Grade
# 0      S1    Male        CSE     A
# 1      S2  Female         IT     B
# 2      S3  Female        CSE     A
# 3      S4    Male        ECE     C
# 4      S5    Male         IT     B

# %%
# Q.1) Count Students in Each Grade
#Find how many students obtained each grade.

print(df['Grade'].value_counts())
# Out:
# Grade
# B    24
# A    22
# C    14
# Name: count, dtype: int64

# %%
# Q.2) Percentage Distribution of Grades

print(df['Grade'].value_counts(normalize=True)*100)
# Out:
# Grade
# B    40.000000
# A    36.666667
# C    23.333333
# Name: proportion, dtype: float64

# %%
# Q.3) Number of Students in each Department

print(df['Department'].value_counts())
# Out:
# Department
# CSE           20
# IT            18
# ECE           11
# Mechanical    11
# Name: count, dtype: int64

# %%
# Q.4) Gender Distribution

print(df['Gender'].value_counts())# Q.5) Gender Vs Grade Analysis

print(pd.crosstab(df['Gender'], df['Grade']))
# Out:
# Gender
# Male      30
# Female    30
# Name: count, dtype: int64
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9

# %%
# Q.5) Gender Vs Grade Analysis

print(pd.crosstab(df['Gender'], df['Grade']))
# Out:
# Grade    A   B  C
# Gender
# Female  14  11  5
# Male     8  13  9

# %%
# Q.6) Department Vs Gender

print(pd.crosstab(df['Department'], df['Gender']))
# Out:
# Gender      Female  Male
# Department
# CSE             12     8
# ECE              5     6
# IT               9     9
# Mechanical       4     7

# %%
# Q.7) Department Vs Grade Percentage

print(pd.crosstab(df['Department'], df['Grade']))
# Out:
# Grade        A  B  C
# Department
# CSE         13  4  3
# ECE          2  5  4
# IT           7  8  3
# Mechanical   0  7  4

# %%
# Q.8) Grouping Data (Departmentwise)

print(df.groupby('Department').value_counts())
# Out:
# Department  Student  Gender  Grade
# CSE         S1       Male    A        1
#             S11      Male    A        1
#             S14      Female  A        1
#             S17      Male    B        1
#             S20      Female  A        1
#             S23      Male    A        1
#             S26      Female  C        1
#             S3       Female  A        1
#             S30      Female  B        1
#             S33      Male    A        1
#             S36      Female  A        1
#             S40      Female  A        1
#             S43      Male    C        1
#             S46      Female  B        1
#             S50      Female  A        1
#             S53      Male    A        1
#             S56      Female  A        1
#             S6       Female  A        1
#             S60      Female  B        1
#             S9       Male    C        1
# ECE         S10      Female  B        1
#             S16      Female  A        1
# ...
